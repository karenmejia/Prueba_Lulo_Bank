# %% [markdown]
# ### **ANÁLISIS EXPLORATORIO DE LOS DATOS (EDA)**

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
from utils.df_generation import normalize
from utils.constants import constants
import os
import pandas as pd

# %%
pd.set_option('display.max_columns', 70)

# %%
main_path = constants.main_path.value
json_path = os.path.join(main_path, 'json')

# Procesar datos
df = normalize(json_path)
df.head()
# Out:
#         id                                                url     name  \
# 0  2730586  https://www.tvmaze.com/episodes/2730586/neznos...  Серия 1
# 1  2730587  https://www.tvmaze.com/episodes/2730587/neznos...  Серия 2
# 2  2730588  https://www.tvmaze.com/episodes/2730588/neznos...  Серия 3
# 3  2730589  https://www.tvmaze.com/episodes/2730589/neznos...  Серия 4
# 4  2730590  https://www.tvmaze.com/episodes/2730590/neznos...  Серия 5
#
#    season  number     type     airdate airtime                   airstamp  \
# 0       2     1.0  regular  2024-01-01          2024-01-01T00:00:00+00:00
# 1       2     2.0  regular  2024-01-01          2024-01-01T00:00:00+00:00
# 2       2     3.0  regular  2024-01-01          2024-01-01T00:00:00+00:00
# 3       2     4.0  regular  2024-01-01          2024-01-01T00:00:00+00:00
# 4       2     5.0  regular  2024-01-01          2024-01-01T00:00:00+00:00
#
#    runtime  image summary  rating.average  \
# 0     23.0    NaN    None             NaN
# ...

# %%
# tamaño del dataframe 
df.shape
# Out:
# (4814, 66)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4814 entries, 0 to 4813
# Data columns (total 66 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   id                                          4814 non-null   int64
#  1   url                                         4814 non-null   object
#  2   name                                        4814 non-null   object
#  3   season                                      4814 non-null   int64
#  4   number                                      4785 non-null   float64
#  5   type                                        4814 non-null   object
#  6   airdate                                     4814 non-null   object
#  7   airtime                                     4814 non-null   object
#  8   airstamp                                    4814 non-null   object
#  9   runtime                                     4360 non-null   float64
# ...

# %%
df['rating.average'].value_counts()
# Out:
# rating.average
# 9.0     32
# 7.0     28
# 7.3     24
# 8.5     24
# 7.5     20
# 7.8     16
# 6.7     16
# 8.0     15
# 6.5     15
# 7.7     13
# 6.0     12
# 8.7     12
# 6.8     10
# 7.4      8
# 6.6      8
# 8.3      8
# 7.6      7
# 7.1      7
# 8.4      5
# 8.1      5
# 8.8      4
# 7.9      4
# 6.4      4
# 4.0      4
# 3.5      4
# 10.0     4
# 9.2      4
# 6.3      3
# 9.5      3
# 8.2      3
# 6.9      3
# 3.0      3
# 7.2      3
# 9.4      3
# 5.5      3
# 9.3      2
# 6.2      2
# 8.9      2
# 5.7      1
# 5.4      1
# 5.0      1
# 9.7      1
# 4.5      1
# Name: count, dtype: int64

# %%
df['_embedded.show.genres'].value_counts()
# Out:
# _embedded.show.genres
#                                  1503
# [Drama, Romance]                  307
# [Drama]                           295
# [Comedy]                          259
# [Romance]                         227
#                                  ...
# [Travel, History]                   1
# [Comedy, Crime, Mystery]            1
# [Children, Family, History]         1
# [Fantasy]                           1
# [Adventure, Children, Family]       1
# Name: count, Length: 149, dtype: int64

# %%
df['_embedded.show.schedule.days'] = df['_embedded.show.schedule.days'].replace('[]', '')

# %%
df['_embedded.show.schedule.days'] = df['_embedded.show.schedule.days'].apply(lambda x: ''if x == [] else x)

# %%
df['_embedded.show.genres'] = df['_embedded.show.genres'].apply(lambda x: 'None' if x == [] else x)

# %%
df.head()
# Out:
#         id                                                url     name  \
# 0  2730586  https://www.tvmaze.com/episodes/2730586/neznos...  Серия 1
# 1  2730587  https://www.tvmaze.com/episodes/2730587/neznos...  Серия 2
# 2  2730588  https://www.tvmaze.com/episodes/2730588/neznos...  Серия 3
# 3  2730589  https://www.tvmaze.com/episodes/2730589/neznos...  Серия 4
# 4  2730590  https://www.tvmaze.com/episodes/2730590/neznos...  Серия 5
#
#    season  number     type     airdate airtime                   airstamp  \
# 0       2     1.0  regular  2024-01-01          2024-01-01T00:00:00+00:00
# 1       2     2.0  regular  2024-01-01          2024-01-01T00:00:00+00:00
# 2       2     3.0  regular  2024-01-01          2024-01-01T00:00:00+00:00
# 3       2     4.0  regular  2024-01-01          2024-01-01T00:00:00+00:00
# 4       2     5.0  regular  2024-01-01          2024-01-01T00:00:00+00:00
#
#    runtime  image summary  rating.average  \
# 0     23.0    NaN    None             NaN
# ...
