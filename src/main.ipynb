# %%
from api_extraction import APIExtraction
from data_processing import DataProcessor
from ydata_profiling import ProfileReport

# %%
# Instancia de APIExtraction
api = APIExtraction(base_url="http://api.tvmaze.com/schedule/web", save_directory="../json")
#datos = api.fetch_data("2024-01-01")
api.save_json(datos, "series_2024-01-01.json")

# Procesar datos
processor = DataProcessor("../json/tv_shows.json")
df = processor.load_data()
#df_cleaned = processor.clean_data(df)
df.head()
# Out:
# Datos obtenidos correctamente.
# Datos guardados en ../json\tv_shows.json
#         id                                                url     name  \
# 0  2730586  https://www.tvmaze.com/episodes/2730586/neznos...  Серия 1
# 1  2730587  https://www.tvmaze.com/episodes/2730587/neznos...  Серия 2
# 2  2730588  https://www.tvmaze.com/episodes/2730588/neznos...  Серия 3
# 3  2730589  https://www.tvmaze.com/episodes/2730589/neznos...  Серия 4
# 4  2730590  https://www.tvmaze.com/episodes/2730590/neznos...  Серия 5
#
#    season  number     type     airdate airtime                   airstamp  \
# 0       2     1.0  regular  2024-01-01          2024-01-01T00:00:00+00:00
# 1       2     2.0  regular  2024-01-01          2024-01-01T00:00:00+00:00
# 2       2     3.0  regular  2024-01-01          2024-01-01T00:00:00+00:00
# 3       2     4.0  regular  2024-01-01          2024-01-01T00:00:00+00:00
# 4       2     5.0  regular  2024-01-01          2024-01-01T00:00:00+00:00
#
# ...

# %%
df.shape
# Out:
# (189, 15)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 189 entries, 0 to 188
# Data columns (total 15 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   id         189 non-null    int64
#  1   url        189 non-null    object
#  2   name       189 non-null    object
#  3   season     189 non-null    int64
#  4   number     188 non-null    float64
#  5   type       189 non-null    object
#  6   airdate    189 non-null    object
#  7   airtime    189 non-null    object
#  8   airstamp   189 non-null    object
#  9   runtime    162 non-null    float64
#  10  rating     189 non-null    object
#  11  image      44 non-null     object
#  12  summary    71 non-null     object
#  13  _links     189 non-null    object
#  14  _embedded  189 non-null    object
# dtypes: float64(2), int64(2), object(11)
# memory usage: 22.3+ KB

# %%
import pandas as pd
import json

# %%
with open("../json/series_2024-01-01.json", "r", encoding = "utf-8") as f:
    json_data = json.load(f)

# %%
# Procesar datos
df = pd.json_normalize(json_data)
#df_cleaned = processor.clean_data(df)
df.head()
# Out:
#         id                                                url     name  \
# 0  2730586  https://www.tvmaze.com/episodes/2730586/neznos...  Серия 1
# 1  2730587  https://www.tvmaze.com/episodes/2730587/neznos...  Серия 2
# 2  2730588  https://www.tvmaze.com/episodes/2730588/neznos...  Серия 3
# 3  2730589  https://www.tvmaze.com/episodes/2730589/neznos...  Серия 4
# 4  2730590  https://www.tvmaze.com/episodes/2730590/neznos...  Серия 5
#
#    season  number     type     airdate airtime                   airstamp  \
# 0       2     1.0  regular  2024-01-01          2024-01-01T00:00:00+00:00
# 1       2     2.0  regular  2024-01-01          2024-01-01T00:00:00+00:00
# 2       2     3.0  regular  2024-01-01          2024-01-01T00:00:00+00:00
# 3       2     4.0  regular  2024-01-01          2024-01-01T00:00:00+00:00
# 4       2     5.0  regular  2024-01-01          2024-01-01T00:00:00+00:00
#
#    runtime  ...  image.medium image.original  _embedded.show.network.id  \
# ...
